# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fishData = pd.read_csv("fish.csv")
fishData
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
plt.scatter(fishData["Weight"],fishData["Length1"], label=fishData["Species"])
plt.show()

# %%
import seaborn as sns
ax = sns.scatterplot(x="Weight", y="Length1",
                     hue="Species",
#                      style="Species", 
                     data=fishData)
ax.set_ylabel("Vertical Length (cm)")
ax.set_xlabel("Weight (g)")
h, l = ax.get_legend_handles_labels()
h, l = h[1:], l[1:]
ax.legend(h, l, loc='lower left', bbox_to_anchor= (0.01, 1.01), ncol=4,
            borderaxespad=0, frameon=True, fontsize=11)
plt.savefig("weight-vs-vertical_length.png")

# %%
import seaborn as sns
ax = sns.scatterplot(x="Height", y="Length1",
                     hue="Species",
#                      style="Species", 
                     data=fishData)
ax.set_ylabel("Height (cm)")
ax.set_xlabel("Weight (g)")
h, l = ax.get_legend_handles_labels()
h, l = h[1:], l[1:]
ax.legend(h, l, loc='lower left', bbox_to_anchor= (0.01, 1.01), ncol=4,
            borderaxespad=0, frameon=True, fontsize=11)
plt.savefig("weight-vs-height.png")

# %%
dir(l)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alpha',
#  '_animated',
#  '_approx_text_height',
#  '_auto_legend_data',
#  '_axes',
#  '_bbox_to_anchor',
#  '_clipon',
#  '_clippath',
#  '_contains',
#  '_custom_handler_map',
#  '_default_handler_map',
#  '_draggable',
#  '_drawFrame',
#  '_find_best_position',
#  '_findoffset',
#  '_fontsize',
#  '_get_anchored_bbox',
#  '_get_clipping_extent_bbox',
#  '_get_loc',
#  '_gid',
#  '_in_layout',
#  '_init_legend_box',
#  '_label',
#  '_legend_box',
#  '_legend_handle_box',
#  '_legend_title_box',
#  '_loc',
#  '_loc_real',
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
np.random.seed(1974)

font = {'size'  : 12}

matplotlib.rc('font', **font)

# Generate Data
x = fishData["Weight"]
y = fishData["Length1"]
labels = fishData["Species"]
df = pd.DataFrame(dict(x=x, y=y, label=labels))

groups = df.groupby('label')

# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.x, group.y, marker='+', linestyle='', ms=12, label=name)  
plt.legend(title="Species")
plt.xlabel("Weight (g)")
plt.ylabel("Length1: Vertical Length (cm)")
plt.savefig('Length1.png')
plt.show()

# %%
# Generate Data
x = fishData["Weight"]
y = fishData["Length2"]
labels = fishData["Species"]

df = pd.DataFrame(dict(x=x, y=y, label=labels))
groups = df.groupby('label')

# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.x, group.y, marker='+', linestyle='', ms=12, label=name)  
plt.legend(title="Species")
plt.xlabel("Weight (g)")
plt.ylabel("Length2: Diagonal Length (cm)")
plt.savefig('Length2.png')
plt.show()

# %%
# Generate Data
x = fishData["Weight"]
y = fishData["Length3"]
labels = fishData["Species"]

df = pd.DataFrame(dict(x=x, y=y, label=labels))
groups = df.groupby('label')

# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.x, group.y, marker='+', linestyle='', ms=12, label=name) 
plt.legend(title="Species")
plt.xlabel("Weight (g)")
plt.ylabel("Length3: Cross Length (cm)")
plt.savefig('Length3.png')
plt.show()

# %%
# Generate Data
x = fishData["Weight"]
y = fishData["Height"]
labels = fishData["Species"]

df = pd.DataFrame(dict(x=x, y=y, label=labels))
groups = df.groupby('label')

# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.x, group.y, marker='+', linestyle='', ms=12, label=name)  
plt.legend(title="Species")
plt.xlabel("Weight (g)")
plt.ylabel("Height (cm)")
plt.savefig('Height.png')
plt.show()
# Out:
# /Users/jeremy/anaconda3/envs/dh/lib/python3.7/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Unrecognized location '7'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
# Generate Data
x = fishData["Weight"]
y = fishData["Width"]
labels = fishData["Species"]

df = pd.DataFrame(dict(x=x, y=y, label=labels))
groups = df.groupby('label')

# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.x, group.y, marker='+', linestyle='', ms=12, label=name)  
plt.legend(title="Species")
plt.xlabel("Weight (g)")
plt.ylabel("Width (cm)")
plt.savefig('Width.png')
plt.show()
